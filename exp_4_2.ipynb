# %% [markdown]
# <a href="https://colab.research.google.com/github/madhu-smita-12/ML_Lab/blob/main/exp_4_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# Alpha values
alpha = np.array([1, 1, 1])

# Support vectors
support_vectors = np.array([
    [0, 1, 1],
    [0, 2, -1],
    [-1, 0, 2]
])

# Class labels
y = np.array([1, -1, -1])

# Input vector
x = np.array([0.2, 0.1, 0.4])

# Decision function
f = 0

for i in range(len(alpha)):
    dot_product = np.dot(support_vectors[i], x)
    contribution = alpha[i] * y[i] * dot_product
    f += contribution

print("Decision function value:", f)

predicted_label = np.sign(f)
print("Predicted label:", int(predicted_label))
