# %% [markdown]
# <a href="https://colab.research.google.com/github/madhu-smita-12/ML_Lab/blob/main/exp_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# Input points
points = np.array([
    [2, 3],
    [3, 4],
    [6, 6],
    [7, 7]
])

# Number of clusters
k = 2

# Initial centroids (you can change)
centroids = np.array([
    [2, 3],
    [6, 6]
])

def euclidean_distance(p1, p2):
    return np.sqrt(np.sum((p1 - p2) ** 2))

# K-means algorithm
for iteration in range(10):  # max iterations
    clusters = [[] for _ in range(k)]

    # Assign points to nearest centroid
    for point in points:
        distances = [euclidean_distance(point, centroid) for centroid in centroids]
        cluster_index = np.argmin(distances)
        clusters[cluster_index].append(point)

    # Convert to numpy arrays
    clusters = [np.array(cluster) for cluster in clusters]

    # Update centroids
    new_centroids = []
    for cluster in clusters:
        if len(cluster) > 0:
            new_centroids.append(np.mean(cluster, axis=0))
        else:
            new_centroids.append(np.array([0, 0]))

    new_centroids = np.array(new_centroids)

    # Stop if no change
    if np.all(centroids == new_centroids):
        break

    centroids = new_centroids

# Output
for i, cluster in enumerate(clusters):
    print(f"Cluster {i+1}: {cluster}")

print("Final Centroids:", centroids)
# Out:
# Cluster 1: [[2 3]
#  [3 4]]
# Cluster 2: [[6 6]
#  [7 7]]
# Final Centroids: [[2.5 3.5]
#  [6.5 6.5]]
