# %% [markdown]
# <a href="https://colab.research.google.com/github/madhu-smita-12/ML_Lab/blob/main/exp_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# Number of clusters
k = 2

# Data points
points = np.array([
    [1, 1],
    [2, 1],
    [4, 3],
    [5, 4]
])

# Initial centroids (choose first k points)
centroids = points[:k]

# Function to calculate Euclidean distance
def distance(p1, p2):
    return np.sqrt(np.sum((p1 - p2) ** 2))

# K-means algorithm
for iteration in range(10):  # run fixed iterations
    clusters = [[] for _ in range(k)]

    # Assign points to nearest centroid
    for point in points:
        distances = [distance(point, centroid) for centroid in centroids]
        cluster_index = np.argmin(distances)
        clusters[cluster_index].append(point)

    # Update centroids
    new_centroids = []
    for cluster in clusters:
        if len(cluster) > 0:
            new_centroids.append(np.mean(cluster, axis=0))
        else:
            new_centroids.append(np.zeros(2))

    new_centroids = np.array(new_centroids)

    # Stop if centroids do not change
    if np.all(centroids == new_centroids):
        break

    centroids = new_centroids

# Output result
print("Final Centroids:")
print(centroids)

print("\nClusters:")
for i, cluster in enumerate(clusters):
    print(f"Cluster {i+1}: {cluster}")
# Out:
# Final Centroids:
# [[1.5 1. ]
#  [4.5 3.5]]
#
# Clusters:
# Cluster 1: [array([1, 1]), array([2, 1])]
# Cluster 2: [array([4, 3]), array([5, 4])]
